# %%
#KNN classification algorithm

from sklearn import datasets
from sklearn.neighbors import KNeighborsClassifier 

#loading dataset

#iris = datasets.load_iris()
print(iris.DESCR)
features = iris.data    
labels = iris.target     

#print(features[0],labels[0])     

'''1.model declear 
   2.model fit
    3.predic kora dawa
     4.output dakha '''

#training the classifier

clf = KNeighborsClassifier()
clf.fit(features,labels)

preds = clf.predict([[3.1,1,1,1]])
print(preds)

# %%
#Train a logistic classifier to predict whether a flower is iris virginica or not


from sklearn import datasets
from sklearn.linear_model import LogisticRegression
iris=datasets.load_iris()
import numpy as np
import matplotlib.pyplot as plt

x=iris["data"][:,3:]
y=(iris["target"]==2).astype(np.int64)


#train a logistic regression classifier
clf=LogisticRegression()
clf.fit(x,y)
example=clf.predict([[2.6]])
print(example)

#Using matplotlib to plot the visualization taking petal width into consideration
X_new=np.linspace(0,3,1000).reshape(-1,1)
y_prob=clf.predict_proba(X_new)

plt.plot(X_new,y_prob[:,1],"g-", label="virginica")
plt.show()
# print(X_new)


# print(list(iris.keys()))
# print(iris['data'].shape)
# print(iris['target'])
# print(y)
# Out:
# [1]

# %%
import numpy as np
import pandas as pd
import seaborn as sns

data = pd.read_csv(r"c:\Users\Acer\Downloads\Housing.csv")

#understand the data

data.head()
data.describe()
data.columns
data.shape

#clean

data.nunique()
data["parking"].unique()

data.isnull().sum()

# %%
dragon = data.drop(["bathrooms","furnishingstatus"], axis=1)
dragon.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'stories', 'mainroad', 'guestroom',
#        'basement', 'hotwaterheating', 'airconditioning', 'parking',
#        'prefarea'],
#       dtype='object')

# %%
dragon.shape
# Out:
# (545, 11)

# %%
pd.set_option('future.no_silent_downcasting',True)
df = pd.DataFrame(dragon)
df.replace({'yes': 1,'no':0},inplace=True)

# %%
#analyze

correlation = dragon.corr()
sns.heatmap(correlation,xticklabels=correlation.columns,yticklabels=correlation.columns,annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(dragon)

# %%
sns.relplot(x='area', y='price', hue= 'stories', data= dragon)

# %%
sns.displot(dragon['area'],bins=5)
